# %% [markdown]
# <a href="https://colab.research.google.com/github/dataqueenpend/Projects-/blob/Kaggle-Projects/new_house_prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
dftrain = pd.read_csv("/content/train.csv")
dftest = pd.read_csv("/content/test.csv")

# %%
dftest
# Out:
#         Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0     1461          20       RH  ...    2010        WD        Normal
# 1     1462          20       RL  ...    2010        WD        Normal
# 2     1463          60       RL  ...    2010        WD        Normal
# 3     1464          60       RL  ...    2010        WD        Normal
# 4     1465         120       RL  ...    2010        WD        Normal
# ...    ...         ...      ...  ...     ...       ...           ...
# 1454  2915         160       RM  ...    2006        WD        Normal
# 1455  2916         160       RM  ...    2006        WD       Abnorml
# 1456  2917          20       RL  ...    2006        WD       Abnorml
# 1457  2918          85       RL  ...    2006        WD        Normal
# 1458  2919          60       RL  ...    2006        WD        Normal
#
# [1459 rows x 80 columns]

# %%
dftrain
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
dftrain.SalePrice.hist()

# %% [markdown]
# Creating folds

# %%
dftrain["kfold"] = -1

# %%
from sklearn import model_selection
kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=0)
for fold,(train_ind, valid_ind) in enumerate(kf.split(X=dftrain)):
    dftrain.loc[valid_ind, "kfold"] = fold

# %%
#Checking if the folds are in the df
dftrain.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleCondition  SalePrice kfold
# 0   1          60       RL  ...         Normal     208500     3
# 1   2          20       RL  ...         Normal     181500     0
# 2   3          60       RL  ...         Normal     223500     0
# 3   4          70       RL  ...        Abnorml     140000     3
# 4   5          60       RL  ...         Normal     250000     0
#
# [5 rows x 82 columns]

# %%
#Checking the folds counts and distribution
dftrain.kfold.value_counts()
# Out:
# 4    292
# 3    292
# 2    292
# 1    292
# 0    292
# Name: kfold, dtype: int64

# %%
dftrain[dftrain.kfold == 0].SalePrice.hist()

# %%
dftrain[dftrain.kfold == 1].SalePrice.hist()

# %%
dftrain[dftrain.kfold == 2].SalePrice.hist()

# %%
dftrain[dftrain.kfold == 3].SalePrice.hist()

# %%
dftrain[dftrain.kfold == 4].SalePrice.hist()

# %% [markdown]
# Distibution is not perctly similar. But we'll see what it will give us.

# %%
dftrain = dftrain.set_index('Id')

# %%
dftrain
# Out:
#       MSSubClass MSZoning  LotFrontage  ...  SaleCondition SalePrice kfold
# Id                                      ...
# 1             60       RL         65.0  ...         Normal    208500     3
# 2             20       RL         80.0  ...         Normal    181500     0
# 3             60       RL         68.0  ...         Normal    223500     0
# 4             70       RL         60.0  ...        Abnorml    140000     3
# 5             60       RL         84.0  ...         Normal    250000     0
# ...          ...      ...          ...  ...            ...       ...   ...
# 1456          60       RL         62.0  ...         Normal    175000     4
# 1457          20       RL         85.0  ...         Normal    210000     2
# 1458          70       RL         66.0  ...         Normal    266500     1
# 1459          20       RL         68.0  ...         Normal    142125     3
# 1460          20       RL         75.0  ...         Normal    147500     2
#
# [1460 rows x 81 columns]

# %%
# Categorical columns in the training data
object_cols = [col for col in dftrain.columns if dftrain[col].dtype == "object"]

# Columns that can be safely ordinal encoded
good_label_cols = [col for col in object_cols if 
                   set(dftest[col]).issubset(set(dftrain[col]))]
        
# Problematic columns that will be dropped from the dataset
bad_label_cols = list(set(object_cols)-set(good_label_cols))
        
print('Categorical columns that will be ordinal encoded:', good_label_cols)
print('\nCategorical columns that will be dropped from the dataset:', bad_label_cols)
# Out:
# Categorical columns that will be ordinal encoded: ['Street', 'Alley', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleCondition']
#
# Categorical columns that will be dropped from the dataset: ['Exterior1st', 'Exterior2nd', 'Functional', 'SaleType', 'KitchenQual', 'MSZoning', 'Utilities']

# %%
dftest_copy = dftest.copy()
dftrain_copy = dftrain.copy()

# %%
dftrain = dftrain.drop(columns=bad_label_cols)

# %%
dftrain
# Out:
#       MSSubClass  LotFrontage  LotArea  ... SaleCondition SalePrice kfold
# Id                                      ...
# 1             60         65.0     8450  ...        Normal    208500     3
# 2             20         80.0     9600  ...        Normal    181500     0
# 3             60         68.0    11250  ...        Normal    223500     0
# 4             70         60.0     9550  ...       Abnorml    140000     3
# 5             60         84.0    14260  ...        Normal    250000     0
# ...          ...          ...      ...  ...           ...       ...   ...
# 1456          60         62.0     7917  ...        Normal    175000     4
# 1457          20         85.0    13175  ...        Normal    210000     2
# 1458          70         66.0     9042  ...        Normal    266500     1
# 1459          20         68.0     9717  ...        Normal    142125     3
# 1460          20         75.0     9937  ...        Normal    147500     2
#
# [1460 rows x 74 columns]

# %%
#useful_features  = [col for col in dftrain.columns if col not in ('kfold', 'id', 'SalePrice')]
categorical_cols = [col for col in dftrain.columns if dftrain[col].dtype == 'object']
#categorical_cols = list(set(categorical_cols) - set(bad_label_cols))

numerical_cols = [col for col in dftrain if dftrain[col].dtype in ['int64', 'float64']]
#numerical_cols = list(set(numerical_cols) - set(bad_label_cols))

# %%
dftrain[categorical_cols]
# Out:
#      Street Alley LotShape LandContour  ... PoolQC  Fence MiscFeature SaleCondition
# Id                                      ...
# 1      Pave   NaN      Reg         Lvl  ...    NaN    NaN         NaN        Normal
# 2      Pave   NaN      Reg         Lvl  ...    NaN    NaN         NaN        Normal
# 3      Pave   NaN      IR1         Lvl  ...    NaN    NaN         NaN        Normal
# 4      Pave   NaN      IR1         Lvl  ...    NaN    NaN         NaN       Abnorml
# 5      Pave   NaN      IR1         Lvl  ...    NaN    NaN         NaN        Normal
# ...     ...   ...      ...         ...  ...    ...    ...         ...           ...
# 1456   Pave   NaN      Reg         Lvl  ...    NaN    NaN         NaN        Normal
# 1457   Pave   NaN      Reg         Lvl  ...    NaN  MnPrv         NaN        Normal
# 1458   Pave   NaN      Reg         Lvl  ...    NaN  GdPrv        Shed        Normal
# 1459   Pave   NaN      Reg         Lvl  ...    NaN    NaN         NaN        Normal
# ...

# %%
dftrain[numerical_cols]
# Out:
#       MSSubClass  LotFrontage  LotArea  ...  YrSold  SalePrice  kfold
# Id                                      ...
# 1             60         65.0     8450  ...    2008     208500      3
# 2             20         80.0     9600  ...    2007     181500      0
# 3             60         68.0    11250  ...    2008     223500      0
# 4             70         60.0     9550  ...    2006     140000      3
# 5             60         84.0    14260  ...    2008     250000      0
# ...          ...          ...      ...  ...     ...        ...    ...
# 1456          60         62.0     7917  ...    2007     175000      4
# 1457          20         85.0    13175  ...    2010     210000      2
# 1458          70         66.0     9042  ...    2010     266500      1
# 1459          20         68.0     9717  ...    2010     142125      3
# 1460          20         75.0     9937  ...    2008     147500      2
#
# [1460 rows x 38 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

categorical_transformer= Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant')),
    ('ordenc', OrdinalEncoder(
                        handle_unknown="use_encoded_value",
                        unknown_value=-999))])

numerical_transformer = SimpleImputer(strategy = 'most_frequent')

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

pipeline = Pipeline(steps=[('prep',preprocessor), ('m', model)])

# %%
preprocessor.fit_transform(dftrain)
# Out:
# array([[6.000e+01, 6.500e+01, 8.450e+03, ..., 4.000e+00, 4.000e+00,
#         4.000e+00],
#        [2.000e+01, 8.000e+01, 9.600e+03, ..., 4.000e+00, 4.000e+00,
#         4.000e+00],
#        [6.000e+01, 6.800e+01, 1.125e+04, ..., 4.000e+00, 4.000e+00,
#         4.000e+00],
#        ...,
#        [7.000e+01, 6.600e+01, 9.042e+03, ..., 0.000e+00, 2.000e+00,
#         4.000e+00],
#        [2.000e+01, 6.800e+01, 9.717e+03, ..., 4.000e+00, 4.000e+00,
#         4.000e+00],
#        [2.000e+01, 7.500e+01, 9.937e+03, ..., 4.000e+00, 4.000e+00,
#         4.000e+00]])

# %%
dftransformed = pd.DataFrame(preprocessor.fit_transform(dftrain))
dftransformed
# Out:
#         0     1        2    3    4       5   ...   68   69   70   71   72   73
# 0     60.0  65.0   8450.0  7.0  5.0  2003.0  ...  4.0  2.0  3.0  4.0  4.0  4.0
# 1     20.0  80.0   9600.0  6.0  8.0  1976.0  ...  4.0  2.0  3.0  4.0  4.0  4.0
# 2     60.0  68.0  11250.0  7.0  5.0  2001.0  ...  4.0  2.0  3.0  4.0  4.0  4.0
# 3     70.0  60.0   9550.0  7.0  5.0  1915.0  ...  4.0  2.0  3.0  4.0  4.0  0.0
# 4     60.0  84.0  14260.0  8.0  5.0  2000.0  ...  4.0  2.0  3.0  4.0  4.0  4.0
# ...    ...   ...      ...  ...  ...     ...  ...  ...  ...  ...  ...  ...  ...
# 1455  60.0  62.0   7917.0  6.0  5.0  1999.0  ...  4.0  2.0  3.0  4.0  4.0  4.0
# 1456  20.0  85.0  13175.0  6.0  6.0  1978.0  ...  4.0  2.0  3.0  2.0  4.0  4.0
# 1457  70.0  66.0   9042.0  7.0  9.0  1941.0  ...  4.0  2.0  3.0  0.0  2.0  4.0
# 1458  20.0  68.0   9717.0  5.0  6.0  1950.0  ...  4.0  2.0  3.0  4.0  4.0  4.0
# 1459  20.0  75.0   9937.0  5.0  6.0  1965.0  ...  4.0  2.0  3.0  4.0  4.0  4.0
#
# ...

# %% [markdown]
# Why there is no predictions?

# %%
#useful_features

# %%
#dftrain.columns

# %%
final_predictions = []
for fold in range(5):
    xtrain =  dftrain[dftrain.kfold != fold].reset_index(drop=True)
    xvalid = dftrain[dftrain.kfold == fold].reset_index(drop=True)
    xtest = dftest.copy()

    ytrain = xtrain.SalePrice
    yvalid = xvalid.SalePrice
    
    xtrain = xtrain.drop(columns=['SalePrice'])
    xvalid = xvalid.drop(columns=['SalePrice'])

    model = RandomForestRegressor(random_state=fold, n_jobs=4)
    
    #xtrain = pipeline.fit_transform(xtrain)
    pipeline.fit(xtrain,ytrain)
    #xvalid = pipeline.transform(xvalid)
    pipeline.transform(xvalid)
    #xtest = pipeline.transform(dftest)

    preds_valid = model.predict(xvalid)
    test_preds = model.predict(xtest)
    final_predictions.append(test_preds)
    print(fold, mean_squared_error(yvalid, preds_valid, squared=False))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SalePrice'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
